# %%
# Import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## load preprocess and convert image to blob

# %%
# load the image to detect
img_to_detect = cv2.imread('images/scene8.jpg')

# %%
img_to_detect.shape
# Out:
# (720, 1280, 3)

# %%
# get height and width of image
img_height = img_to_detect.shape[0]
img_width = img_to_detect.shape[1]

# %%
plt.imshow(img_to_detect)

# %%
# convert to blob to pass into model
# recommended scale factor is 0.007843 and width, height of blob is 300,300 and mean of 255 is 127.5
img_blob = cv2.dnn.blobFromImage(img_to_detect,swapRB=True, crop=False)

# %%
# Set of 81 class labels in alphabetical order (background + rest of 20 classes)

class_labels = ["person","bicycle","car","motorbike","aeroplane","bus","train","truck","boat","traffic light","fire hydrant","street sign","stop sign","parking meter","bench","bird","cat","dog","horse","sheep","cow","elephant","bear","zebra","giraffe","hat","backpack","umbrella","shoe","eye glasses","handbag","tie","suitcase","frisbee","skis","snowboard","sports ball","kite","baseball bat","baseball glove","skateboard","surfboard","tennis racket","bottle","plate","wine glass","cup","fork","knife","spoon","bowl","banana","apple","sandwich","orange","broccoli","carrot","hot dog","pizza","donut","cake","chair","sofa","pottedplant","bed","mirror","diningtable","window","desk","toilet","door","tv","laptop","mouse","remote","keyboard","cell phone","microwave","oven","toaster","sink","refrigerator","blender","book","clock","vase","scissors","teddy bear","hair drier","toothbrush"]

# %% [markdown]
# ## Load Pre-trained model and get prediction

# %%
# Loading pre-trained model from prototext and Tensorflow files 

maskrcnn = cv2.dnn.readNetFromTensorflow('datasets/maskrcnn_buffermodel.pb','datasets/maskrcnn_bufferconfig.txt')

# %%
# Input preprocessed blob into model and pass through the model
maskrcnn.setInput(img_blob)

# %%
# obtain the detection predictions (both box and mask) by the model using forward() method
(obj_detections_boxes, obj_detections_masks) = maskrcnn.forward(["detection_out_final","detection_masks"])

# %%
obj_detections_boxes.shape
# Out:
# (1, 1, 100, 7)

# %% [markdown]
# ## Loop over detections, Get Class labels, Box co-ordinates

# %%
# Loop over the detections
no_of_detections = obj_detections_boxes.shape[2]

for index in np.arange(0, no_of_detections):
    prediction_confidence = obj_detections_boxes[0,0,index,2]
    # take only predictions with confidence more than 20%
    if prediction_confidence > 0.1:
        # get the prediction label
        predicted_class_index = int(obj_detections_boxes[0,0,index,1])
        predicted_class_label = class_labels[predicted_class_index]
        # obtain the bounding box co-ordinates for the actual image from resized image size
        bounding_box = obj_detections_boxes[0,0,index,3:7] * np.array([img_width, img_height, img_width, img_height])
        (start_x_pt, start_y_pt, end_x_pt, end_y_pt) = bounding_box.astype("int")
        
        # Print the prediction in console
        predicted_class_label = "{}: {:.2f}%".format(class_labels[predicted_class_index],prediction_confidence*100)
        print("predicted object {}: {}".format(index+1,predicted_class_label))

        # Draw rectangle and text in the image
        cv2.rectangle(img_to_detect, (start_x_pt,start_y_pt), (end_x_pt,end_y_pt), (0,0,255),2)
        cv2.putText(img_to_detect, predicted_class_label, (start_x_pt,start_y_pt-5), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255,0,0),1)
# Out:
# predicted object 1: car: 99.34%
# predicted object 2: car: 99.10%
# predicted object 3: car: 98.94%
# predicted object 4: car: 98.85%
# predicted object 5: car: 98.83%
# predicted object 6: car: 98.40%
# predicted object 7: car: 98.24%
# predicted object 8: car: 98.04%
# predicted object 9: car: 98.03%
# predicted object 10: car: 97.58%
# predicted object 11: car: 97.48%
# predicted object 12: car: 97.42%
# predicted object 13: bus: 97.41%
# predicted object 14: car: 97.35%
# predicted object 15: car: 97.23%
# predicted object 16: car: 96.78%
# predicted object 17: car: 96.64%
# predicted object 18: car: 96.19%
# predicted object 19: car: 95.60%
# predicted object 20: car: 94.09%
# predicted object 21: car: 94.09%
# predicted object 22: car: 93.52%
# predicted object 23: car: 93.44%
# predicted object 24: car: 92.99%
# predicted object 25: bus: 92.49%
# predicted object 26: car: 92.18%
# predicted object 27: car: 92.10%
# predicted object 28: car: 91.97%
# predicted object 29: car: 91.74%
# predicted object 30: car: 91.33%
# predicted object 31: car: 89.62%
# predicted object 32: car: 89.43%
# predicted object 33: car: 89.33%
# predicted object 34: person: 86.37%
# predicted object 35: car: 86.35%
# predicted object 36: car: 85.26%
# predicted object 37: car: 84.58%
# predicted object 38: person: 84.48%
# predicted object 39: car: 82.79%
# predicted object 40: car: 82.49%
# predicted object 41: car: 82.46%
# predicted object 42: car: 81.98%
# predicted object 43: person: 78.53%
# predicted object 44: car: 76.07%
# predicted object 45: person: 73.92%
# predicted object 46: car: 73.70%
# predicted object 47: person: 73.22%
# predicted object 48: car: 69.94%
# predicted object 49: car: 69.68%
# predicted object 50: person: 68.75%
# predicted object 51: car: 66.91%
# predicted object 52: car: 66.41%
# predicted object 53: boat: 59.87%
# predicted object 54: person: 54.77%
# predicted object 55: car: 51.82%
# predicted object 56: bus: 48.36%
# predicted object 57: car: 45.61%
# predicted object 58: person: 44.84%
# predicted object 59: car: 43.04%
# predicted object 60: truck: 42.45%
# predicted object 61: person: 41.26%
# predicted object 62: car: 37.93%
# predicted object 63: car: 36.98%
# predicted object 64: person: 36.02%
# predicted object 65: truck: 34.34%
# predicted object 66: umbrella: 32.74%
# predicted object 67: truck: 32.29%
# predicted object 68: truck: 31.85%

# %%
# Show the output image
plt.imshow(img_to_detect)

cv2.imshow("Detection Output", img_to_detect)
cv2.waitKey(0)
cv2.destroyAllWindows()
