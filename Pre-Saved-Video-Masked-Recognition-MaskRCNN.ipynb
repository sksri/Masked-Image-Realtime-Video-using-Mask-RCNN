# %%
# Import libraries
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Streaming webcam videos
webcam_video_stream = cv2.VideoCapture('images/video_sample.mp4')

while True:
    ret,current_frame = webcam_video_stream.read()
    img_to_detect = current_frame
    # get height and width of image
    img_height = img_to_detect.shape[0]
    img_width = img_to_detect.shape[1]
    
    # convert to blob to pass into model
    # recommended scale factor is 0.007843 and width, height of blob is 300,300 and mean of 255 is 127.5
    img_blob = cv2.dnn.blobFromImage(img_to_detect,swapRB=True, crop=False)
    
    # Set of 90 class labels in alphabetical order (background + rest of 20 classes)
    class_labels = ["person","bicycle","car","motorbike","aeroplane","bus","train","truck","boat","traffic light","fire hydrant","street sign","stop sign","parking meter","bench","bird","cat","dog","horse","sheep","cow","elephant","bear","zebra","giraffe","hat","backpack","umbrella","shoe","eye glasses","handbag","tie","suitcase","frisbee","skis","snowboard","sports ball","kite","baseball bat","baseball glove","skateboard","surfboard","tennis racket","bottle","plate","wine glass","cup","fork","knife","spoon","bowl","banana","apple","sandwich","orange","broccoli","carrot","hot dog","pizza","donut","cake","chair","sofa","pottedplant","bed","mirror","diningtable","window","desk","toilet","door","tv","laptop","mouse","remote","keyboard","cell phone","microwave","oven","toaster","sink","refrigerator","blender","book","clock","vase","scissors","teddy bear","hair drier","toothbrush"]
    
    # Declare list of colors as an array
    # Green, Blue, Red, Cyan, Yellow, Purple
    # Split based on ',' and for every split, change type to init
    # convert that to numpy array to apply color mask to the image numpy array

    class_colors = ["0,255,0","0,0,255","255,0,0","255,255,0","0,255,255","255,0,255"]
    class_colors = [np.array(every_color.split(",")).astype("int") for every_color in class_colors]
    class_colors = np.array(class_colors)
    class_colors = np.tile(class_colors,(15,1))
    
    # Loading pre-trained model from prototext and Tensorflow files 
    maskrcnn = cv2.dnn.readNetFromTensorflow('datasets/maskrcnn_buffermodel.pb','datasets/maskrcnn_bufferconfig.txt')
    
    # Input preprocessed blob into model and pass through the model
    maskrcnn.setInput(img_blob)
    
    # obtain the detection predictions (both box and mask) by the model using forward() method
    (obj_detections_boxes, obj_detections_masks) = maskrcnn.forward(["detection_out_final","detection_masks"])
    
    
    # Loop over the detections
    no_of_detections = obj_detections_boxes.shape[2]

    for index in np.arange(0, no_of_detections):
        prediction_confidence = obj_detections_boxes[0,0,index,2]
        # take only predictions with confidence more than 50%
        if prediction_confidence > 0.5:
            # get the prediction label
            predicted_class_index = int(obj_detections_boxes[0,0,index,1])
            predicted_class_label = class_labels[predicted_class_index]
            # obtain the bounding box co-ordinates for the actual image from resized image size
            bounding_box = obj_detections_boxes[0,0,index,3:7] * np.array([img_width, img_height, img_width, img_height])
            (start_x_pt, start_y_pt, end_x_pt, end_y_pt) = bounding_box.astype("int")

            # obtain width and height of bounding box
            bounding_box_width = end_x_pt-start_x_pt
            bounding_box_height = end_y_pt-start_y_pt

            # obtain the bounding mask co-ordinates for current detection index
            object_mask = obj_detections_masks[index, predicted_class_index]
            # resize mask to bounding_box_width and bounding_box_height
            object_mask = cv2.resize(object_mask, (bounding_box_width,bounding_box_height))
            # minimum threshold value to convert float based mask array to binary
            # if true respective values will be true and vice versa
            object_mask = (object_mask>0.3)

            # slice the image array based on bounding box rectangle which is the roi
            object_region_of_interest = img_to_detect[start_y_pt:end_y_pt, start_x_pt:end_x_pt]
            # slice the roi array based on the bounding box
            object_region_of_interest = object_region_of_interest[object_mask]

            # get a random mask color from numpy array of colors
            #mask_color = random.choice(class_colors)
            mask_color = class_colors[predicted_class_index]

            # add a transparent color cover to the region of inertest
            roi_color_transparent_cover = ((0.3 * mask_color) + (0.5 * object_region_of_interest)).astype("uint8")
            # place the transparent color cover over the actual image
            img_to_detect[start_y_pt:end_y_pt, start_x_pt:end_x_pt][object_mask] = roi_color_transparent_cover

            # convert the color numpy array as a list and apply text and box
            mask_color = [int(c) for c in mask_color]

            # Print the prediction in console
            predicted_class_label = "{}: {:.2f}%".format(class_labels[predicted_class_index],prediction_confidence*100)
            print("predicted object {}: {}".format(index+1,predicted_class_label))

            # Draw rectangle and text in the image
            cv2.rectangle(img_to_detect, (start_x_pt,start_y_pt), (end_x_pt,end_y_pt), mask_color,2)
            cv2.putText(img_to_detect, predicted_class_label, (start_x_pt,start_y_pt-5), cv2.FONT_HERSHEY_COMPLEX, 0.5, mask_color,1)

    # Show the output image
    #plt.imshow(img_to_detect)

    cv2.imshow("Detection Output", img_to_detect)
    # terminate while loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# releasing the stream and the camera
webcam_video_stream.release()
# close all opencv windows
cv2.destroyAllWindows()
# Out:
# predicted object 1: car: 90.03%
# predicted object 2: truck: 71.87%
# predicted object 3: truck: 67.83%
# predicted object 4: car: 65.36%
# predicted object 5: person: 64.22%
# predicted object 6: person: 60.21%
# predicted object 7: truck: 57.48%
# predicted object 8: person: 54.34%
# predicted object 1: car: 89.77%
# predicted object 2: person: 72.44%
# predicted object 3: car: 70.63%
# predicted object 4: person: 69.97%
# predicted object 5: bus: 60.29%
# predicted object 6: truck: 56.57%
# predicted object 7: truck: 55.74%
# predicted object 8: person: 53.53%
# predicted object 1: car: 88.94%
# predicted object 2: car: 80.35%
# predicted object 3: person: 77.88%
# predicted object 4: bus: 61.79%
# predicted object 5: person: 61.60%
# predicted object 6: car: 60.26%
# predicted object 7: person: 56.30%
# predicted object 1: car: 87.21%
# predicted object 2: person: 79.73%
# predicted object 3: truck: 76.70%
# predicted object 4: car: 69.71%
# predicted object 5: bus: 68.61%
# predicted object 6: person: 59.77%
# predicted object 7: person: 54.84%
# predicted object 1: car: 87.48%
# predicted object 2: person: 79.54%
# predicted object 3: truck: 74.84%
# predicted object 4: bus: 71.31%
# predicted object 5: car: 70.77%
# predicted object 6: person: 59.81%
# predicted object 7: person: 52.64%
# predicted object 1: car: 88.73%
# predicted object 2: person: 81.94%
# predicted object 3: car: 65.32%
# predicted object 4: person: 63.30%
# predicted object 5: bus: 61.91%
# predicted object 6: car: 58.73%
# predicted object 7: person: 56.48%
# predicted object 1: car: 89.39%
# predicted object 2: person: 83.94%
# predicted object 3: bus: 68.97%
# predicted object 4: person: 66.22%
# predicted object 5: car: 64.39%
# predicted object 6: car: 60.00%
# predicted object 7: person: 54.84%
# predicted object 8: person: 54.06%
# predicted object 9: truck: 51.53%
# predicted object 10: car: 50.42%
# predicted object 11: person: 50.10%
# predicted object 1: car: 88.37%
# predicted object 2: person: 85.94%
# predicted object 3: car: 85.94%
# predicted object 4: bus: 72.73%
# predicted object 5: truck: 58.28%
# predicted object 6: person: 58.21%
# predicted object 7: car: 54.40%
# predicted object 8: person: 51.13%
# predicted object 1: car: 89.06%
# predicted object 2: car: 88.99%
# predicted object 3: person: 84.97%
# predicted object 4: car: 78.74%
# predicted object 5: bus: 68.32%
# predicted object 6: car: 58.91%
# predicted object 7: person: 56.95%
# predicted object 8: truck: 55.13%
# predicted object 9: person: 50.92%
# predicted object 1: car: 88.28%
# predicted object 2: car: 86.33%
# predicted object 3: person: 84.80%
# predicted object 4: car: 73.75%
# predicted object 5: bus: 71.49%
# predicted object 6: car: 65.99%
# predicted object 7: person: 59.51%
# predicted object 8: truck: 54.76%
# predicted object 1: car: 88.57%
# predicted object 2: car: 86.23%
# predicted object 3: person: 84.84%
# predicted object 4: car: 72.39%
# predicted object 5: bus: 70.40%
# predicted object 6: car: 63.10%
# predicted object 7: person: 59.18%
# predicted object 8: truck: 53.01%
# predicted object 9: person: 50.64%
# predicted object 1: car: 90.42%
# predicted object 2: car: 88.47%
# predicted object 3: person: 83.79%
# predicted object 4: person: 67.39%
# predicted object 5: car: 65.13%
# predicted object 6: truck: 57.55%
# predicted object 7: truck: 56.07%
# predicted object 8: bus: 54.82%
# predicted object 9: person: 51.52%
# predicted object 10: car: 50.28%
# predicted object 1: car: 90.79%
# predicted object 2: car: 88.43%
# predicted object 3: person: 72.88%
# predicted object 4: person: 69.00%
# predicted object 5: car: 64.00%
# predicted object 6: person: 55.12%
# predicted object 7: truck: 53.73%
# predicted object 8: bus: 52.06%
# predicted object 9: car: 50.14%
# predicted object 1: car: 93.62%
# predicted object 2: car: 88.15%
# predicted object 3: person: 69.32%
# predicted object 4: car: 65.54%
# predicted object 5: car: 61.65%
# predicted object 6: bus: 61.41%
# predicted object 7: person: 53.19%
# predicted object 8: person: 52.81%
# predicted object 9: person: 50.16%
# predicted object 1: car: 93.05%
# predicted object 2: car: 87.55%
# predicted object 3: car: 83.89%
# predicted object 4: car: 72.66%
# predicted object 5: bus: 65.17%
# predicted object 6: person: 64.83%
# predicted object 7: person: 59.55%
# predicted object 8: person: 54.13%
# predicted object 1: car: 88.00%
# predicted object 2: car: 64.62%
# predicted object 3: person: 64.13%
# predicted object 4: car: 59.14%
# predicted object 5: truck: 58.53%
# predicted object 6: person: 56.21%
# predicted object 7: car: 52.58%
# predicted object 1: car: 88.16%
# predicted object 2: car: 83.22%
# predicted object 3: car: 69.54%
# predicted object 4: truck: 66.30%
# predicted object 5: person: 56.24%
# predicted object 6: person: 55.89%
# predicted object 1: car: 88.38%
# predicted object 2: car: 76.61%
# predicted object 3: truck: 72.74%
# predicted object 4: person: 69.35%
# predicted object 5: car: 62.21%
# predicted object 6: person: 54.22%
# predicted object 7: car: 51.12%
# predicted object 1: car: 87.85%
# predicted object 2: car: 81.52%
# predicted object 3: car: 80.79%
# predicted object 4: car: 69.26%
# predicted object 5: truck: 67.12%
# predicted object 6: person: 66.42%
# predicted object 7: truck: 55.02%
# predicted object 8: person: 52.60%
# predicted object 9: person: 51.92%
# predicted object 1: car: 89.06%
# predicted object 2: car: 84.56%
# predicted object 3: car: 81.32%
# predicted object 4: car: 78.32%
# predicted object 5: person: 72.36%
# predicted object 6: truck: 66.65%
# predicted object 7: person: 59.91%
# predicted object 8: car: 58.70%
# predicted object 9: person: 50.55%
# predicted object 1: car: 92.09%
# predicted object 2: car: 87.41%
# predicted object 3: car: 85.33%
# predicted object 4: person: 82.50%
# predicted object 5: car: 78.37%
# predicted object 6: truck: 67.40%
# predicted object 7: person: 55.10%
# predicted object 1: car: 87.73%
# predicted object 2: person: 87.37%
# predicted object 3: car: 87.35%
# predicted object 4: car: 84.70%
# predicted object 5: truck: 73.93%
# predicted object 6: person: 55.44%
# predicted object 7: car: 54.19%
# predicted object 8: person: 53.03%
# predicted object 9: person: 51.52%
# predicted object 10: person: 50.77%
# predicted object 1: car: 87.34%
# predicted object 2: person: 87.31%
# predicted object 3: car: 86.52%
# predicted object 4: car: 83.29%
# predicted object 5: truck: 72.23%
# predicted object 6: person: 54.87%
# predicted object 7: person: 54.19%
# predicted object 8: car: 52.36%
# predicted object 9: person: 51.55%
# predicted object 10: person: 50.45%
# predicted object 1: person: 87.50%
# predicted object 2: car: 87.34%
# predicted object 3: car: 86.61%
# predicted object 4: car: 83.30%
# predicted object 5: truck: 72.46%
# predicted object 6: person: 55.19%
# predicted object 7: person: 54.19%
# predicted object 8: car: 52.36%
# predicted object 9: person: 51.56%
# predicted object 10: person: 50.45%
# predicted object 1: car: 89.80%
# predicted object 2: car: 89.03%
# predicted object 3: car: 87.83%
# predicted object 4: person: 85.11%
# predicted object 5: truck: 72.08%
# predicted object 6: person: 57.98%
# predicted object 1: car: 89.25%
# predicted object 2: car: 87.09%
# predicted object 3: person: 81.47%
# predicted object 4: truck: 76.27%
# predicted object 5: car: 68.31%
# predicted object 6: person: 57.99%
# predicted object 1: car: 89.69%
# predicted object 2: car: 88.18%
# predicted object 3: person: 85.36%
# predicted object 4: truck: 83.43%
# predicted object 5: person: 54.48%
# predicted object 6: person: 52.56%
# predicted object 7: person: 51.56%
# predicted object 1: car: 89.34%
# predicted object 2: car: 88.21%
# predicted object 3: person: 85.76%
# predicted object 4: truck: 78.26%
# predicted object 5: person: 60.16%
# predicted object 6: person: 52.13%
# predicted object 1: car: 89.19%
# predicted object 2: car: 86.97%
# predicted object 3: person: 83.80%
# predicted object 4: truck: 76.92%
# predicted object 5: car: 65.20%
# predicted object 6: person: 62.78%
# predicted object 7: person: 60.16%
# predicted object 8: person: 56.39%
# predicted object 1: car: 88.20%
# predicted object 2: car: 87.96%
# predicted object 3: person: 84.47%
# predicted object 4: truck: 76.39%
# predicted object 5: car: 66.45%
# predicted object 6: person: 62.36%
# predicted object 7: person: 58.32%
# predicted object 8: person: 56.39%
# predicted object 1: car: 89.33%
# predicted object 2: car: 87.00%
# predicted object 3: person: 85.95%
# predicted object 4: truck: 76.72%
# predicted object 5: person: 64.60%
# predicted object 6: person: 63.35%
# predicted object 7: truck: 55.53%
# predicted object 8: person: 54.96%
# predicted object 9: person: 52.97%
# predicted object 1: car: 91.22%
# predicted object 2: car: 87.17%
# predicted object 3: person: 84.92%
# predicted object 4: truck: 77.61%
# predicted object 5: person: 71.51%
# predicted object 6: person: 65.15%
# predicted object 7: person: 56.04%
# predicted object 8: person: 51.45%
# predicted object 9: person: 50.37%
# predicted object 1: car: 90.72%
# predicted object 2: car: 88.47%
# predicted object 3: person: 85.28%
# predicted object 4: truck: 83.45%
# predicted object 5: person: 72.33%
# predicted object 6: person: 58.22%
# predicted object 7: person: 51.81%
# predicted object 8: person: 51.58%
# predicted object 9: person: 50.82%
# predicted object 10: truck: 50.57%
# predicted object 1: car: 91.52%
# predicted object 2: car: 88.79%
# predicted object 3: truck: 80.66%
# predicted object 4: person: 80.00%
# predicted object 5: person: 66.15%
# predicted object 6: truck: 64.07%
# predicted object 7: person: 59.00%
# predicted object 1: car: 92.52%
# predicted object 2: car: 88.32%
# predicted object 3: person: 81.74%
# predicted object 4: truck: 76.55%
# predicted object 5: person: 70.89%
# predicted object 6: person: 70.65%
# predicted object 7: person: 65.83%
# predicted object 8: truck: 61.80%
# predicted object 1: car: 92.28%
# predicted object 2: car: 89.36%
# predicted object 3: person: 81.89%
# predicted object 4: truck: 76.76%
# predicted object 5: truck: 72.63%
# predicted object 6: person: 71.51%
# predicted object 7: person: 70.40%
# predicted object 8: person: 67.55%
# predicted object 1: car: 91.81%
# predicted object 2: car: 88.72%
# predicted object 3: person: 79.95%
# predicted object 4: person: 76.13%
# predicted object 5: person: 73.93%
# predicted object 6: truck: 72.90%
# predicted object 7: person: 63.76%
# predicted object 8: truck: 57.77%
# predicted object 1: car: 92.16%
# predicted object 2: car: 88.49%
# predicted object 3: person: 82.60%
# predicted object 4: person: 80.43%
# predicted object 5: person: 80.16%
# predicted object 6: truck: 75.87%
# predicted object 7: person: 68.64%
# predicted object 1: car: 89.52%
# predicted object 2: car: 86.22%
# predicted object 3: person: 85.70%
# predicted object 4: person: 85.35%
# predicted object 5: person: 78.38%
# predicted object 6: person: 75.96%
# predicted object 7: truck: 64.29%
# predicted object 1: car: 88.89%
# predicted object 2: person: 86.99%
# predicted object 3: car: 86.81%
# predicted object 4: person: 83.85%
# predicted object 5: person: 82.43%
# predicted object 6: person: 71.69%
# predicted object 7: truck: 70.26%
# predicted object 8: person: 52.59%
# predicted object 1: car: 92.26%
# predicted object 2: car: 89.23%
# predicted object 3: person: 86.22%
# predicted object 4: person: 86.20%
# predicted object 5: person: 81.74%
# predicted object 6: person: 70.68%
# predicted object 7: truck: 58.78%
# predicted object 8: person: 55.92%
# predicted object 9: truck: 52.93%
# predicted object 1: car: 92.68%
# predicted object 2: car: 89.42%
# predicted object 3: person: 86.85%
# predicted object 4: person: 86.80%
# predicted object 5: person: 80.14%
# predicted object 6: person: 70.00%
# predicted object 7: truck: 58.03%
# predicted object 8: person: 55.35%
# predicted object 9: truck: 51.94%
# predicted object 10: bus: 51.32%
# predicted object 1: car: 92.24%
# predicted object 2: car: 89.51%
# predicted object 3: person: 89.02%
# predicted object 4: person: 83.11%
# predicted object 5: person: 81.46%
# predicted object 6: person: 72.74%
# predicted object 7: truck: 62.94%
# predicted object 8: person: 59.71%
# predicted object 9: truck: 54.97%
# predicted object 1: car: 92.25%
# predicted object 2: car: 88.72%
# predicted object 3: person: 85.94%
# predicted object 4: person: 85.46%
# predicted object 5: person: 82.56%
# predicted object 6: truck: 65.03%
# predicted object 7: person: 60.34%
# predicted object 8: person: 58.58%
# predicted object 1: car: 92.28%
# predicted object 2: car: 85.72%
# predicted object 3: person: 83.69%
# predicted object 4: person: 83.58%
# predicted object 5: person: 79.26%
# predicted object 6: person: 61.10%
# predicted object 7: person: 60.34%
# predicted object 8: bus: 52.26%
# predicted object 9: car: 50.20%
# predicted object 1: car: 91.35%
# predicted object 2: person: 89.93%
# predicted object 3: car: 86.44%
# predicted object 4: person: 85.54%
# predicted object 5: person: 83.91%
# predicted object 6: person: 61.45%
# predicted object 7: person: 59.92%
# predicted object 8: truck: 59.46%
# predicted object 9: truck: 52.61%
# predicted object 1: car: 90.88%
# predicted object 2: person: 86.60%
# predicted object 3: car: 85.91%
# predicted object 4: person: 83.67%
# predicted object 5: person: 64.88%
# predicted object 6: person: 60.87%
# predicted object 7: person: 55.01%
# predicted object 8: truck: 53.16%
# predicted object 9: car: 53.03%
# predicted object 1: car: 87.72%
# predicted object 2: person: 87.17%
# predicted object 3: person: 87.11%
# predicted object 4: car: 76.30%
# predicted object 5: truck: 68.91%
# predicted object 6: car: 60.77%
# predicted object 7: person: 59.78%
# predicted object 8: person: 58.84%
# predicted object 9: person: 56.03%
# predicted object 10: truck: 51.21%
# predicted object 1: person: 88.58%
# predicted object 2: car: 88.04%
# predicted object 3: person: 87.28%
# predicted object 4: car: 77.36%
# predicted object 5: person: 68.79%
# predicted object 6: truck: 66.58%
# predicted object 7: person: 60.13%
# predicted object 8: person: 59.04%
# predicted object 9: car: 52.40%
# predicted object 1: car: 87.57%
# predicted object 2: person: 84.33%
# predicted object 3: person: 84.09%
# predicted object 4: car: 75.90%
# predicted object 5: person: 69.47%
# predicted object 6: person: 61.08%
# predicted object 7: person: 58.31%
# predicted object 8: car: 57.40%
# predicted object 9: truck: 56.56%
# predicted object 1: car: 87.75%
# predicted object 2: person: 82.26%
# predicted object 3: person: 80.29%
# predicted object 4: car: 76.27%
# predicted object 5: person: 70.31%
# predicted object 6: truck: 67.64%
# predicted object 7: person: 58.44%
# predicted object 8: person: 56.38%
# predicted object 9: truck: 53.16%
# predicted object 10: car: 53.06%
# predicted object 1: car: 86.59%
# predicted object 2: car: 85.59%
# predicted object 3: person: 75.90%
# predicted object 4: person: 75.75%
# predicted object 5: truck: 73.52%
# predicted object 6: person: 59.09%
# predicted object 7: person: 56.70%
# predicted object 8: person: 51.59%
# predicted object 1: car: 86.54%
# predicted object 2: car: 85.31%
# predicted object 3: person: 74.81%
# predicted object 4: person: 73.36%
# predicted object 5: truck: 71.59%
# predicted object 6: person: 61.12%
# predicted object 7: person: 56.38%
# predicted object 8: person: 53.90%
# predicted object 1: car: 86.81%
# predicted object 2: car: 84.13%
# predicted object 3: truck: 74.61%
# predicted object 4: person: 73.14%
# predicted object 5: person: 73.06%
# predicted object 6: person: 59.03%
# predicted object 7: person: 56.60%
# predicted object 8: person: 52.19%
# predicted object 9: truck: 50.90%
# predicted object 1: car: 85.14%
# predicted object 2: car: 78.57%
# predicted object 3: truck: 72.53%
# predicted object 4: person: 72.05%
# predicted object 5: person: 71.35%
# predicted object 6: person: 57.44%
# predicted object 7: person: 56.61%
# predicted object 8: truck: 52.28%
# predicted object 9: person: 51.22%
# predicted object 10: person: 50.45%
# predicted object 1: car: 86.33%
# predicted object 2: car: 85.44%
# predicted object 3: person: 79.46%
# predicted object 4: person: 72.61%
# predicted object 5: truck: 71.36%
# predicted object 6: person: 61.70%
# predicted object 7: person: 56.77%
# predicted object 1: car: 86.50%
# predicted object 2: car: 84.16%
# predicted object 3: truck: 81.18%
# predicted object 4: person: 71.40%
# predicted object 5: person: 69.44%
# predicted object 6: person: 60.18%
# predicted object 7: person: 53.81%
# predicted object 1: car: 86.79%
# predicted object 2: car: 82.65%
# predicted object 3: person: 76.83%
# predicted object 4: truck: 69.73%
# predicted object 5: person: 68.83%
# predicted object 6: person: 60.54%
# predicted object 7: person: 57.66%
